# %% [markdown]
# **NAME- Gadekar Aditi**

# %% [markdown]
# # Step 1: Import necessary libraries:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # Step 2: Load and Prepare your Data:
#  Load your dataset into a pandas DataFrame and extract the independent variable (X) and dependent variable (Y).
#  You might need to preprocess the data to handle missing values and outliers.

# %%
x = np.array([[151],[174],[138],[186],[128],[136],[179],[163],[152],[131]])
y = np.array([[63],[81],[56],[91],[47],[57],[76],[72],[62],[48]])

# %% [markdown]
# # Step 3: Split the Data into Training and Testing Sets:

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# # Step 4: Create and Train the Linear Regression Model:

# %%
model = LinearRegression()
model.fit(x, y)
print("Intercept:", model.intercept_)
print("Coefficient:", model.coef_)
# Out:
# Intercept: [-38.45508708]
# Coefficient: [[0.67461045]]

# %% [markdown]
# # Step 5: Make Predictions:

# %%
X_test = np.array([[12]])
y_pred = model.predict(X_test)
print("Predicted value:", y_pred)
# Out:
# Predicted value: [[-30.35976169]]

# %% [markdown]
# # Step 6: Visualization:
# Calculate evaluation metrics to assess the model's performance
# plotting the regression line

# %%
# plotting the regression line
plt.scatter(x, y, color = 'k', marker = "o", s = 30)

# predicted
plt.plot(x, model.predict(x), color = "b")
plt.title("Simple Linear Regression")
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
